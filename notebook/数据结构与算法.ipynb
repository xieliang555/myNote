# %% [markdown]
# # 二叉树

# %% [markdown]
# ## 二叉树重建

# %% [markdown]
# {1,2,3,4,5,6,7,null,8}:
#
#     - 先序遍历：1，2，4，8，5，3，6，7
#     - 中序遍历：4，8，2，5，1，6，3，7
#     - 后续遍历：8，4，5，2，6，7，3，1
#
#     - 先序+中序重建：(对于每一棵子树：从先序找根，然后中序找左右子树)
#         - 根：1, 左子树：{4,8,2,5},右子树：{6,3,7}
#         - 对于{4,8,2,5}子树：根：2，左子树：{4,8},右子树：{5}
#         - 对于{6,3,7}子树：根：3，左子树：{6},右子树：{7}
#         - 对于{4,8}子树：根：4，左子树：{null}，右子树：{8}
#
#     - 后序+中序重建：(对于每一棵子树，从后序找根，然后中序找左右子树)
#         - 根：1，左子树：{4,8,2,5},右子树：{6,3,7}
#         - 对于{4,8,2,5}子树：根：2，左子树：{4,8},右子树：{5}
#         - 对于{6,3,7}子树：根：3，左子树：{6},右子树：{7}
#         - 对于{4,8}子树：根：4，左子树：{null}，右子树：{8}

# %% [markdown]
# # 逆波兰表达式

# %% [markdown]
# - 中缀表达式不适合计算机计算，转化为后缀（逆波兰）
#     - 中缀表达式：A+B-C/D×E
#     - 后缀表达式：ABCD/-E×+

# %% [markdown]
# ## 中缀转后缀

# %% [markdown]
# 规则如下：
# （1）如vector当前值为操作数,直接保存到结果
# （2）如vector当前值为运算符，且运算符高于栈顶运算符，当前值入栈
# （3）如vector当前值为运算符，且运算符低于栈顶运算符，栈顶退栈 ，保存到结果，然后继续比较
# （4）（当前输入与栈顶）运算符同级（+-或×/）时，当前运算符等级低于栈顶运算符（当前+-低于栈顶+-） ，栈顶退栈
# （5）#等级低于所有运算符（+-×/）
# （6）如当前运算符等于栈顶运算符，且均为#，结束
# 如：
# A+B-C/D×E
#
# | vector遍历 | 栈 | 结果 |
# | --- | --- | --- |
# | A+B-C/D×E# | # |  |
# | +B-C/D×E# | # | A |
# | -C/D×E# | #+ | AB |
# | C/D×E# | #- | AB+ |
# | /D×E# | #- | AB+C |
# | D×E# | #-/ | AB+C |
# | ×E# | #-/ | AB+CD |
# | E# | #-× | AB+CD/ |
# | # | #-× | AB+CD/E |
# | # | #- | AB+CD/E× |
# | # | # | AB+CD/E×- |
#
# **Note**当前#等级等于栈顶#

# %% [markdown]
# ## 计算后缀

# %% [markdown]
# 计算后缀 ABCD/-E×+ 如：（2342/-3×+）
#
# 规则：
# (1) vector当前值是操作数，当前值入栈
# (2) vector当前值是操作符，栈尾两位出栈，并运算，结果入栈
# (3) vector遍历完，结束，输出栈
#
# | vector遍历 | 栈 | 结果 |
# | --- | --- | --- |
# | 2342/-3×+ |  |  |
# | /-3×+ | 2342 |  |
# | -3×+ | 23 | 4/2=2 |
# | -3×+ | 23 | 2 |
# | -3×+ | 232 |  |
# | 3×+ | 2 | 3-1=1 |
# | 3×+ | 2 | 1 |
# | 3×+ | 21 |  |
# | ×+ | 213 |  |
# | + | 2 | 1×3=3 |
# | + | 2 | 3 |
# | + | 23 |  |
# |  |  | 2+3=5 |
# |  | 5 |  |

# %% [markdown]
# # 编程技巧

# %% [markdown]
# - 链表：
#     - 需要改变list顺序时：固定一个dummyHead对象或head指针(head已经赋值)，再定义一个新的指针遍历生成新的list，如：
#         - leetcode：合并链表，固定dummyHead，pCur遍历生成新的list
#         - leetcode：排序链表，固定dummyHead，tail遍历生成新的list
#     - 断链：ListNode* cut(list, n)，将list分成两部分链表，前一部分包含n个node，返回后一部分链表头指针，应用：
#         - leetcode：排序链表
#     - 访问node越界：检查每一个访问过val或next成员的Node指针是否是空指针
#     - 环入口，相交链表：
#         - leetcode：寻找重复数
#         - leetcode: 142. 环形链表 II
#         - leetcode：相交链表
#         - 牛客：链表中环的入口节点 (注意特殊测试例子，只有一个Node)
#
# - 递归：
#     - 二叉树，带返回值的递归：1）确定函数参数列表和返回值 2）构造二叉树，分析遍历顺序 3）明确返回值的意义，返回值的意义唯一 4）根据遍历顺序写代码
#     - 二叉树递归改for循环确定循环次数：int i=1;i<length;i*=2，length根据具体情况确定 leetcode 排序链表
#
# - 排序：
#     - 冒泡排序，选择排序，注意两者原理区别，时间复杂度 o(n^2) 空间复杂度 o(1)
#     - 堆排序，时间复杂度o(nlogn), 空间复杂度o(1)
#     - vector归并，时间复杂度 o(nlogn),空间o(n)
#         - leetcode:排序数组
#     - vector快排，时间复杂度 o(nlogn),空间o(1)
#         - leetcode:排序数组
#         - 牛客：数组中出现次数超过一半的数字（最后注意不要忘记检查中间的数是否超过一半），本题也可以加辅助空间统计每一位数字个数o(n)
#     - list归并(自底向上) 时间复杂度 o(nlogn)，空间o(1)
#         - leetcode: 排序链表
#     - 桶排序(计数排序)，需要额外空间复杂度，有长度限制，通过序列最大最小值确定桶大小，且元素为整型,o(n)
#         - leetcode 数组中的第K个最大元素
#     - 插入排序，适合小长度的已排好序的序列，适合数据流, o(n), o(1)
#         - leetcode 295. 数据流的中位数
#
# - 堆：
#     - 堆是由线性数组维护完全二叉树结构，二叉树的跟节点值大于两个左右子树根节点的值
#     - 堆的操作主要有建堆，插入/删除，堆排序
#         - 建堆：时间复杂度：自底向上0(nlogn)，自顶向下o(n), 空间复杂度：o(1)
#         - 插入/删除：o(logn)
#     - 如何维护两个大小最多相差1的堆，leetcode 295. 数据流的中位数。
#     - 一般对未排序的数组求有关第k个或前k个元素时，利用堆排序相比快排和归并可以快一点，o(nlogk)，但需要额外的空间维护一个大小为k的堆，如：
#         - leetcode: 215. 数组中的第K个最大元素
#         - leetcode: 378. 有序矩阵中第K小的元素
#         - leetcode: 347. 前 K 个高频元素
#         - 剑指offer： 最小的k个数
#
# - 队列：
#     - 滑动窗，涉及到窗的更新(数据过期的pop，新增的数据push):
#         - leetcoce 滑动窗口最大值
#         - 剑指offer 59-1
#         - 剑指offer 59-2
#     - 二叉树层序遍历
#
# - 栈：
#     - 中缀转后缀(逆波兰) leetcode: 基本计算器II
#     - 计算后缀表达式 leetcode: 150. 逆波兰表达式求值
#     - 二叉树先序，中序，后序遍历
#     - 二叉树之字形遍历（双栈）
#
# - 重新定义比较运算符：
#     - leetcode 前 K 个高频元素
#     - leetcode 最大数(注意当输入为[0,0]时输出应该是"0"而不是"00")
#
# - 二分查找（主要思考左右两个指针分别移动的条件，可以与中点与target比较确定，也可以通过中点与端点比较确定）：
#     - leetcode 162. 寻找峰值，看结果是否会取到mid而选择left=mid+1还是left=mid(right=mid-1还是right=mid)
#     - 剑指offer 数字在排序数组中出现的次数
#     - 剑指offer 旋转数组的最小数字  ；leetcode 寻找旋转排序数组中的最小值（分为有序和无序）
#     - leetcode 搜索旋转排序数组（分为有序和无序）
#     - 牛客 geohash编码 写出每一次二分的区间，找到规律
#     - x的平方根
#
# - 动态规划和贪心算法
#     - 一般解决问题有多种选择求最优问题时，可以用贪心算法或动态规划
#     - 贪心算法
#         - 贪心算法是每次决策选择当前状态下的局部最优，如果最后局部最优等于全局最优，则可以用贪心算法解决，否则考虑动态规划
#         - 每一步选择是局部最优，但最终可以收敛到全局最优
#             - 牛客 种花
#         - 每一步选择都是全局最优
#             - 牛客 两两配对差值最小
#             - 乘船问题
#             - 最优装载问题
#             - 牛客 贪吃的小Q
#     - 动态规划：
#         - 如果可以用贪心算法解决，优先贪心算法（更简单）
#         - 子集合(带约束的优化问题) ：子集合问题可由2D数组保存所有状态，但动态规划当前状态的结果仅取决于上一状态的结果，故2D可以优化为1D
#             - leetcode 494 目标和
#             - 牛客 外卖满减
#             - leetcode 单词拆分(与knapsack有相似之处)
#             - leetcode 最大子序和
#         - 当前状态的结果不仅仅取决与上一状态的结果：
#             - leetcode 买卖股票的最佳时机
#             - 青蛙跳台阶 牛客
#             - 变态跳台阶 牛客（可转化为数学问题）
#         - 需要记住临时数组中元素的意义
#             - leetcode: 最长上升子序列(数组第i个元素记录着路径长度为i的末尾值的最小值)
#         - 01背包（考虑了所有背包组合的方案）
#             - 01背包9讲 https://www.cnblogs.com/jbelial/articles/2116074.html
#             - 经典01背包 OJ上无此题
#             - 求方案总数 牛客 小Q的歌单
#             - 完全背包 leetcode 单词拆分 (注意容易出现逻辑错误)
#             - 多重01背包 牛客 考试策略 （注意多重背包问题容易问题考虑不全）
#
#
# - 树
#     - 前缀树，node结点包括一个大小为26的指针数组，和一个bool遍历表示该node是否是字符串的末尾字符 leetcode 208. 实现 Trie (前缀树)
#     - 二叉树
#         - 遍历+全局变量
#             - 二叉树中的最大路径和 leetcode
#             - 二叉树的直径 leetcode
#             - 二叉树中和为某一值的路径 牛客剑指offfe
#             - 二叉树的最近公共祖先
#         - 遍历+返回值
#             - 二叉树的深度 牛客剑指offer
#
# - 数组：
#     - 滑动窗遍历
#         - 牛客OJ：瞌睡 o(n)
#         - 牛客：最长全1串 （滑动窗遍历最好定义前后指针）
#     - 多指针
#         - 牛客OJ：素数对 o(n) 多指针从头遍历
#     - 双指针原地
#         - 剑指offer： 替换空格 o(n) 两指针从后向前遍历
#         - leetcode: 移动零 双指针从前遍历 （有点像替换空格的类型）
#         - 其他： 排序数组中和为k的对数 o(n) 双指针两头遍历
#     - 双指针额外空间
#         - 剑指offer：调整数组顺序使奇数在偶数前面 o(n) 双指针两头遍历
#         - 字符串相加 leetcode
#     - 额外空间统计
#         - 牛客：路由器 时间复杂度从 o(n^2)-> o(n)
#         - leetcode 和为k的连续子数组(通过累加相减实现滑窗) 时间复杂度o(n)
#
# - 分治与分区(partition):
#     - 分治（1分为多个2）
#         - 归并排序
#         - 合并k个有序链表 leetcode
#     - 分区（一分为2）
#         - 快排
#         - 数组的中位数
#
# - 数学
#     - 牛客：翻转数列
#     - 找规律：
#         - 牛客：数对
#         - 牛客：操作序列 时间复杂度 o(n^2)->o(n)
#
# - 利用stl中的map（自动排序）
#     - 牛客： 塔
#     - 牛客： 牛牛找工作（注意审题）

# %% [markdown]
# # 其他

# %% [markdown]
# - 判断奇数 x&1==1
# - 判断偶数 x&1==0
# - 取数组中间下标(偶数取偏左) idx=(vec.size()-1)/2
# - 取数组中间下标(偶数取偏右) idx=(vec.size)/2
# - 去数组中间下标(偶数取偏左) idx=(left+right)/2
#
# - 向下取整 (left+right)>>1
# - 向上取整 （left+right+1)>>1
#
#
# - 获取整型的某一位：如获取8的第4位 int tmp=1; tmp<<=3; int bit=8&tmp;
# - 改变整型的某一位: 如改变8的第3位变为1 int tmp=1; tmp<<=2; int afterSet=8|tmp;
#
#
# - 在for循环中写终止条件 for(int i=0; a[i]>0; i++) 如剑指offer21题插入排序解法
#
# - 数组中从第0个元素起有效还是第1个元素起有效，如青蛙跳台阶是第一个元素有效更方便，第0个元素记为0
# - 字符串技巧：cctype isdigit()/isxdigit()/isalpha()/isalnum()/isblank()/isupper()/islower()/toupper()/tolower()
# - 字符串技巧：x-'A'/x-'a'/x-'0'

# %% [markdown]
# # 易错

# %% [markdown]
# 1. 3/2的返回值是整型，即使(double)3/2仍返回1
#     - 若要返回1.5: 3/double(2)
# 2. 同理，INT_MIN/-1 会溢出，即使(long long)INT_MIN/-1也会溢出，因为INT_MIN,-1默认是int型，使用/返回默认也是int，在强制转换为long long前已经溢出，可以先将INT_MIN或-1强制转化为long long再做除法，此时返回的是long long
#     - cout<<INT_MIN/(long long)(-1)<<endl;
# 3. queue尾部只进不出，deque尾部可进可出
# 4. c++内建数组：int arr[10]; 创建大小为10的数组，故arr[10]访问会越界
#     - 最好使用array<int, 10> arr不容易出错
# 5. int arr[10]和array<int, 10> 都是随机初始化数组，vector<int> arr(10) 默认全部初始化0
# 6. 对野指针判断是否为nullptr
#     - 定义指针时要初始化，置为nullptr；内存释放后，指针指向nullptr

# %% [markdown]
# # 笔试OJ注意

# %% [markdown]
# 1. 不可以用不确定的数来初始化vector的长度，如int n; cin>>n; vector<int> vec(n);
#     - 不用先确定vector的长度，使用push_back来添加数字
# 2. 先写成函数调用形式调试，main函数中进行输入输出，并调用函数，若超时，则不用函数调用的形式，全部在main函数中实现
# 3. 当在sublime上运行成功，在OJ上失败，很有可能是cin有问题
# 4. 没有完全通过，尝试将错误的例子规模变小，并使其通过
# 5. 华为oj连续输入多组测试： int n; while(cin>>n){}  Ctrl+Z或Crtl+D或者非int类型的无效输入可以终止循环（cin>>当输入数据类型和变量类型不匹配是会出错，返回假值）
# 6. 漏了情况未考虑，考虑规模小一点的问题，找到漏掉的情况

# %% [markdown]
# # 笔试真题

# %% [markdown]
# - 京东
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# | 写个快排 | leetcode | 排序数组 |
# | 多个字符串组成的最大数 | leetcode | 最大数 |
# | 最小的k个数 | 剑指offer 牛客 | 最小的k个数 |
# | 求N！的二进制表示中最低位1的位置 | 编程之美 |
#
# - 商汤
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# | 找到链表的环起点 | 剑指offer 牛客 | 链表中环的入口节点 |
#
# - 小米
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# | 数组中和为k的对数 | 其他 | - |
#
# - 阿里
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# |买卖股票 | leetcode | 买卖股票的最佳时机 |
# |公共节点链表怎么找到起始公共节点 | 剑指offer 牛客 | 两个链表的第一个公共节点 |
# |搜索旋转排序数组 | leetcode |
#
#
# - 海康
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# |青蛙跳台阶问题| 牛客 | 跳台阶|
# | 最长上升子序列| leetcode |
# |左旋转字符串| 牛客 剑指offer |
#
#
#
# - 腾讯
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# |合并两个排序链表| leetcode |
# |合并k个排序链表| leetcode |
#
#
# - 头条
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# |对称二叉树| 牛客 剑指offer |
# |最大子序和| leetcode |
# |二叉树中的最大路径和| leetcode|
# | 买卖股票的最佳时机 | leetcode |
# | 单词拆分 | leetcode |
#
#
# - 百度
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# |数组中的第K个最大元素 | leetcode |
# | 二叉树的最近公共祖先 | leetcode |
# | 二叉树的深度 | 牛客剑指offer |
# | 二维数组中的查找 | 牛客剑指offer |
#
# - 其他
#
# | 问题| OJ | 题目  |
# | ------| ------ |
# |把数组所有0移到最后，其余相对顺序不变时间o(n)，空间o(1)| leetcode| 移动零 |
# | 二叉树中和为某一值的路径 | 牛客剑指offer |
# | x的平方根 | leetcode |
# | 字符串相加（大数相加） | leetcode |
